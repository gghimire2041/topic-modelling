# %% [markdown]
# #### Pre-process 1st step

# %%
import pandas as pd
import numpy as np
import os
import re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.preprocessing import Normalizer, normalize
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans, MiniBatchKMeans, AgglomerativeClustering, DBSCAN, SpectralClustering
from sklearn.utils.extmath import randomized_svd
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split

import nltk
from nltk.stem.porter import PorterStemmer
from nltk.chunk import ne_chunk
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords

from nltk.tag import StanfordNERTagger
from string import punctuation
from gensim.models.phrases import Phrases, Phraser
from gensim import corpora, models, similarities, matutils, models
import spacy

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import spacy
# spacy.cli.download("en")

# %%
nlp = spacy.load(name='en_core_web_sm')

# %%
stops = stopwords.words('english')

# %%
extra_stops = ['pct', 'percent', 'cent', 'high', 'low', 'top', 'news', 'topnew', 'topnews', 'GMT', 'BST', 'AM', 'PM',
              'Reuters', 'reuters', 'reuters.com', 'plc', 'PLC', 'visit', 'click', 'thomson', 'Thomson', 'thomsonreuters',
              'suggest', 'feedback', 'alert', 'email', 'best', 'cms', 'CMS', 'pageid', 'livemarket', 'client', 'link',
              'net', 'change', 'chg', 'open', 'site', 'eikon', 'EIKON', 'yld', 'yr', 'say', 'year', 'close', 'performance',
              'perform', 'performs', 'id', 'ID', 'pa', 'report', 'reports', 'reporting', 'share', 'break', 'recent', 'past',
              'point', 'said', 'index', 'data', 'new', 'points', 'market', 'markets', 'bn', 'Bn', 'Mn', 'mn', 'avg', 'average',
              'fell', 'fall', 'rose', 'rise', 'time', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 
               'Sunday', 'people', 'higher', 'lower', 'likely', 'Reporting']

# %%
stops = stops + extra_stops
stops = set(stops)

# %%
def underscore_entities(document):
    spacy = nlp(document)
    
    uds_entities = []
    ent_chars = []
    for i in spacy.ents:
        ent_chars.append((i.start_char, i.end_char))
    
    new_string = []
    for index, item in enumerate(list(str(spacy))):
        for i, j in enumerate(ent_chars):
            if j[0] < index < j[1] and item == ' ':
                item = '_'
        new_string.append(item)

    ns = ''.join(new_string)
    uds_entities.append(ns)
        
    return uds_entities

# %%
def clean_cnbc(article):
    text_to_find = '(CNBC) - '
    try:
        cleaned = article[article.index(text_to_find) + len(text_to_find):]
        return cleaned
    except:
        return article

# %%
def clean_text(raw_text, stop=True):
    raw_text = raw_text.replace('U.S', 'US')
    raw_text = clean_cnbc(raw_text)
    letters_only = re.sub('[^a-zA-Z]', ' ', raw_text)
    letters_only = ' '.join(letters_only.split())
#     underscored = underscore_entities(letters_only)
#     words = underscored[0].split()
    words = letters_only.split()
    
    if stop == True:
        meaningful_words = [w for w in words if not w in stops]
        return( " ".join(meaningful_words))
    else:
        return( " ".join(words))

# %%
df = pd.read_csv('cnbc_news.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Santoli’s Wednesday market notes: Could Septem...
# 1     My take on the early Brexit winners and losers
# 2  Europe&#039;s recovery depends on Renzi&#039;s...
# 3  US Moves Closer to Becoming A Major Shareholde...
# 4  Trump: 'Mission accomplished' on 'perfectly ex...
#
#                                                  url          published_at  \
# 0  https://www.cnbc.com/2021/09/29/santolis-wedne...  2021-09-29T17:09:39Z
# 1  https://www.cnbc.com/2016/06/24/ian-bremmers-t...  2016-06-24T17:50:48Z
# 2  https://www.cnbc.com/2014/03/25/europes-recove...  2014-03-25T17:29:45Z
# 3  https://www.cnbc.com/2009/04/22/us-moves-close...  2009-04-22T19:49:03Z
# 4  https://www.cnbc.com/2018/04/14/trump-mission-...  2018-04-14T14:59:04Z
#
#                     author publisher  \
# 0          Michael Santoli      CNBC
# 1                      NaN      CNBC
# 2                      NaN      CNBC
# 3  Michelle Caruso-Cabrera      CNBC
# 4          Javier E. David      CNBC
#
#                                    short_description  \
# 0  This is the daily notebook of Mike Santoli, CN...
# 1  This commentary originally ran on Facebook. Bo...
# 2  In spring, ambitious reforms began in Italy. U...
# 3  The US government is increasingly likely to co...
# 4                                                NaN
#
#                                             keywords  \
# 0  cnbc, Premium, Articles, Investment strategy, ...
# 1  Articles, Politics, Europe News, European Cent...
# 2  Articles, Business News, Economy, Europe Econo...
# 3  cnbc, Articles, General Motors Co, Business Ne...
# 4  cnbc, Articles, George W. Bush, Vladimir Putin...
#
#                                         header_image  \
# 0  https://image.cnbcfm.com/api/v1/image/10694960...
# 1  https://fm.cnbc.com/applications/cnbc.com/reso...
# 2  https://fm.cnbc.com/applications/cnbc.com/reso...
# 3  https://image.cnbcfm.com/api/v1/image/24947979...
# 4  https://image.cnbcfm.com/api/v1/image/10513177...
#
#                                      raw_description  \
# 0  <div class="group"><p><em>This is the daily no...
# 1                                                NaN
# 2                                                NaN
# 3  <div class="group"><p>The US government is inc...
# 4  <div class="group"></div>,<div class="group"><...
#
#                                          description  \
# 0  This is the daily notebook of Mike Santoli, CN...
# 1                                                NaN
# 2                                                NaN
# 3  The US government is increasingly likely to co...
# 4  President Donald Trump hailed the U.S.-led int...
#
#                    scraped_at
# 0  2021-10-30T14:11:23.709372
# 1  2021-10-30T14:11:23.820139
# 2   2021-10-30T14:11:23.85471
# 3  2021-10-30T14:11:24.261143
# 4   2021-10-30T14:11:24.48949

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              625 non-null    object
#  1   url                625 non-null    object
#  2   published_at       625 non-null    object
#  3   author             397 non-null    object
#  4   publisher          625 non-null    object
#  5   short_description  609 non-null    object
#  6   keywords           625 non-null    object
#  7   header_image       619 non-null    object
#  8   raw_description    594 non-null    object
#  9   description        593 non-null    object
#  10  scraped_at         625 non-null    object
# dtypes: object(11)
# memory usage: 53.8+ KB

# %%
df['cleaned_text'] = df['description'].apply(clean_cnbc)

# %%
df.sample(10)
# Out:
#                                                  title  \
# 374                         Amanda Campbell: Compatent
# 449  CNBC Program Changes for Saturday, 11/15 & Sun...
# 456  Trump officials say China pursuing 'blame game...
# 151  Gold as Collateral: Could This Solve the Euro ...
# 51                                           39. Nexmo
# 555  Google bought $750 million Lenovo stake on Jan...
# 512  UPDATE 2-Serb central bank raises key rate to ...
# 458    After-hours buzz: AIG, CBS, King Digital & more
# 49   OPEC comments show lost relevance ahead of mee...
# 548  There won’t be a summer rate hike, so I’ll foc...
#
#                                                    url          published_at  \
# 374  https://www.cnbc.com/2016/12/07/amanda-campbel...  2016-12-07T14:17:33Z
# 449  https://www.cnbc.com/2014/11/12/cnbc-program-c...  2014-11-12T17:49:15Z
# 456  https://www.cnbc.com/2019/06/04/trump-official...  2019-06-04T01:22:15Z
# 151  https://www.cnbc.com/2012/11/05/gold-as-collat...  2012-11-05T06:36:34Z
# 51   https://www.cnbc.com/2014/06/16/disruptors-in-...  2014-06-17T10:09:51Z
# 555  https://www.cnbc.com/2014/02/06/google-bought-...  2014-02-07T04:14:11Z
# 512  https://www.cnbc.com/2012/10/09/update-2serb-c...  2012-10-09T13:32:00Z
# 458  https://www.cnbc.com/2015/02/12/after-hours-bu...  2015-02-12T22:09:35Z
# 49   https://www.cnbc.com/2015/11/23/opec-comments-...  2015-11-23T20:57:10Z
# 548  https://www.cnbc.com/2016/06/06/there-wont-be-...  2016-06-06T16:44:27Z
#
#           author publisher                                  short_description  \
# 374          NaN      CNBC  Meet Amanda Campbell, 24 from Kingston. She's ...
# 449          NaN      CNBC  (ALL TIMES ARE IN ET) Saturday, 11/15/2014:  1...
# 456          NaN      CNBC  U.S. President Donald Trump's administration s...
# 151          NaN      CNBC  Debt-crippled euro zone countries could see th...
# 51           NaN      CNBC  Founders: Tony Jamous (CEO), Eric Nadalin     ...
# 555          NaN      CNBC  Internet search company Google Inc bought a 5....
# 512          NaN      CNBC  * Rate rise of 25 basis points tied to inflati...
# 458  Karma Allen      CNBC  Check out which companies are making headlines...
# 49    Patti Domm      CNBC  Comments from Saudi Arabian officials stirred ...
# 548    Annie Pei      CNBC  Despite all signs from Fed Chair Janet Yellen ...
#
#                                               keywords  \
# 374  cnbc, Articles, Business News, Leadership, Ent...
# 449  cnbc, Articles, CNBC Information and Policies,...
# 456  cnbc, Articles, Politics, U.S. Economy, Trade,...
# 151  cnbc, Articles, Business News, Economy, Europe...
# 51   Articles, Technology, CNBC Disruptors 2014, Mo...
# 555  cnbc, Articles, Alphabet Class A, Lenovo Group...
# 512  cnbc, Articles, Europe, Poland, Eastern Europe...
# 458  cnbc, Articles, Market Insider, American Inter...
# 49   cnbc, Articles, Market Insider, Oil and Gas, C...
# 548  cnbc, Articles, SPDR S&P Oil & Gas Exploration...
#
#                                           header_image  \
# 374  https://image.cnbcfm.com/api/v1/image/10415174...
# 449  https://sc.cnbcfm.com/applications/cnbc.com/st...
# 456  https://image.cnbcfm.com/api/v1/image/10588390...
# 151  https://image.cnbcfm.com/api/v1/image/10019620...
# 51   https://fm.cnbc.com/applications/cnbc.com/reso...
# 555  https://image.cnbcfm.com/api/v1/image/10039872...
# 512  https://sc.cnbcfm.com/applications/cnbc.com/st...
# 458  https://image.cnbcfm.com/api/v1/image/10227052...
# 49   https://image.cnbcfm.com/api/v1/image/10205379...
# 548  https://image.cnbcfm.com/api/v1/image/10368009...
#
#                                        raw_description  \
# 374  <div class="group"><p>  Meet Amanda Campbell, ...
# 449  <div class="group"><p>  <strong><span>(ALL TIM...
# 456  <div class="group"><p><a href="https://www.cnb...
# 151  <div class="group"><p>Debt-crippled euro zone ...
# 51                                                 NaN
# 555  <div class="group"><p>Internet search company ...
# 512  <div class="group"><p>* Rate rise of 25 basis ...
# 458  <div class="group"><p>  <em>Check out which co...
# 49   <div class="group"><p>  Comments from Saudi Ar...
# 548  <div class="group"><p>  Despite all signs from...
#
#                                            description  \
# 374  Meet Amanda Campbell, 24 from Kingston. She's ...
# 449  (ALL TIMES ARE IN ET) Saturday, 11/15/2014:  1...
# 456  U.S. President Donald Trump's administration s...
# 151  Debt-crippled euro zone countries could see th...
# 51                                                 NaN
# 555  Internet search company Google Inc bought a 5....
# 512  * Rate rise of 25 basis points tied to inflati...
# 458  Check out which companies are making headlines...
# 49   Comments from Saudi Arabian officials stirred ...
# 548  Despite all signs from Fed Chair Janet Yellen ...
#
#                      scraped_at  \
# 374  2021-10-30T14:12:12.537178
# 449  2021-10-30T14:12:22.096386
# 456  2021-10-30T14:12:22.662418
# 151  2021-10-30T14:11:43.654753
# 51   2021-10-30T14:11:31.112864
# 555  2021-10-30T14:12:37.333137
# 512  2021-10-30T14:12:32.280763
# 458  2021-10-30T14:12:23.066931
# 49   2021-10-30T14:11:30.557706
# 548  2021-10-30T14:12:36.619382
#
#                                           cleaned_text
# 374  Meet Amanda Campbell, 24 from Kingston. She's ...
# 449  (ALL TIMES ARE IN ET) Saturday, 11/15/2014:  1...
# 456  U.S. President Donald Trump's administration s...
# 151  Debt-crippled euro zone countries could see th...
# 51                                                 NaN
# 555  Internet search company Google Inc bought a 5....
# 512  * Rate rise of 25 basis points tied to inflati...
# 458  Check out which companies are making headlines...
# 49   Comments from Saudi Arabian officials stirred ...
# 548  Despite all signs from Fed Chair Janet Yellen ...
